# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(font='Arial')

# %%
resales = 'abrnliunr_q,abrpricnr_q,abrsalunr_q,abrvolcnr_q,acanliunr_q,acapricnr_q,acasalunr_q,acavolcnr_q,aednliunr_q,aedpricnr_q,aedsalunr_q,aedvolcnr_q,afmnliunr_q,afmpricnr_q,afmsalunr_q,afmvolcnr_q,agpnliunr_q,agppricnr_q,agpsalunr_q,agpvolcnr_q,alenliunr_q,alepricnr_q,alesalunr_q,alevolcnr_q,almnliunr_q,almpricnr_q,almsalunr_q,almvolcnr_q,amenliunr_q,amepricnr_q,amesalunr_q,amevolcnr_q,anenliunr_q,anepricnr_q,anesalunr_q,anevolcnr_q,arenliunr_q,arepricnr_q,aresalunr_q,arevolcnr_q,awenliunr_q,awepricnr_q,awesalunr_q,awevolcnr_q,azznliunr_q,azzpricnr_q,azzsalunr_q,azzvolcnr_q'.split(',')
starts = 'acasamurr,acasemurr,acasrmurr,acassmurr,acastmurr,aedsamurr,aedsemurr,aedsrmurr,aedssmurr,aedstmurr,agpsalurr,agpselurr,agpsrlurr,agpsslurr,agpstlurr,alesalurr,aleselurr,alesrlurr,alesslurr,alestlurr,amesalurr,ameselurr,amesrlurr,amesslurr,amestlurr,aresalurr,areselurr,aresrlurr,aresslurr,arestlurr,awbsalurr,awbselurr,awbsrlurr,awbsslurr,awbstlurr,azzsauurr,azzseuurr,azzsruurr,azzssuurr,azzstuurr'.split(',')

# %%
sale_dfs = [pd.read_csv('./data/pareto/'+file+'.csv',index_col=0) for file in resales]
starts_dfs=[pd.read_csv('./data/pareto/'+file+'.csv',index_col=0) for file in starts]

# %%
sale_df = pd.concat(sale_dfs,axis=1)
starts_df = pd.concat(starts_dfs,axis=1)

# %%
sale_df.index = pd.DatetimeIndex(sale_df.index)
starts_df.index = pd.DatetimeIndex(starts_df.index)

# %%
sale_df
# Out:
#             ABRNLIUNR_Q  ABRPRICNR_Q  ABRSALUNR_Q  ABRVOLCNR_Q  ACANLIUNR_Q  \
# 1980-01-01          NaN          NaN          NaN          NaN       4963.0
# 1980-04-01          NaN          NaN          NaN          NaN       5462.0
# 1980-07-01          NaN          NaN          NaN          NaN       5386.0
# 1980-10-01          NaN          NaN          NaN          NaN       3933.0
# 1981-01-01          NaN          NaN          NaN          NaN       5984.0
# ...                 ...          ...          ...          ...          ...
# 2021-04-01        266.0     263359.0        188.0      49512.0      17388.0
# 2021-07-01        184.0     240811.0        152.0      36603.0      11684.0
# 2021-10-01        124.0     238385.0        116.0      27653.0       7293.0
# 2022-01-01        198.0     250284.0        166.0      41547.0      16043.0
# 2022-04-01        217.0     264821.0        151.0      39988.0      16845.0
#
# ...

# %%
starts_df
# Out:
#             ACASAMURR  ACASEMURR  ACASRMURR  ACASSMURR  ACASTMURR  AEDSAMURR  \
# 1980-01-01      187.0       62.0        4.0      166.0      419.0      317.0
# 1980-02-01      110.0      112.0       79.0      367.0      668.0      387.0
# 1980-03-01      132.0      146.0      203.0      443.0      924.0       61.0
# 1980-04-01       65.0       90.0       47.0      459.0      661.0      484.0
# 1980-05-01      236.0       86.0      201.0      385.0      908.0      130.0
# ...               ...        ...        ...        ...        ...        ...
# 2022-04-01      518.0      176.0      208.0      609.0     1511.0      790.0
# 2022-05-01      953.0      118.0      173.0      525.0     1769.0      694.0
# 2022-06-01     1004.0      134.0      194.0      551.0     1883.0      124.0
# 2022-07-01     1026.0      118.0      212.0      523.0     1879.0      556.0
# 2022-08-01      393.0      110.0      169.0      510.0     1182.0      319.0
#
# ...

# %%
total_starts = [i for i in list(starts_df.columns) if i[3:5]=='ST']

# %%
total_starts
# Out:
# ['ACASTMURR',
#  'AEDSTMURR',
#  'AGPSTLURR',
#  'ALESTLURR',
#  'AMESTLURR',
#  'ARESTLURR',
#  'AWBSTLURR',
#  'AZZSTUURR']

# %%
starts_df_annual =starts_df.resample('A').sum()

# %%
fig, ax = plt.subplots(figsize=(12,6))
sns.barplot(x=starts_df_annual.index,y='AZZSTUURR',data = starts_df_annual)
fig.get_figure().autofmt_xdate()
fig.suptitle('Starts, Alberta')
# Out:
# Text(0.5, 0.98, 'Starts, Alberta')

# %%
starts_df_annual['Alberta_CMA']=starts_df_annual['ACASTMURR']+starts_df_annual['AEDSTMURR']+starts_df_annual['ALESTLURR']+starts_df_annual['ARESTLURR']
starts_df_annual['Alberta_exCMA']=starts_df_annual['AZZSTUURR']-starts_df_annual['Alberta_CMA']
starts_df_annual['Calgary_Edmonton']=starts_df_annual['ACASTMURR']+starts_df_annual['AEDSTMURR']
starts_df_annual['Alberta_small_CMA']=starts_df_annual['Alberta_CMA']-starts_df_annual['Calgary_Edmonton']

# %%
fig, ax = plt.subplots(figsize=(12,6))
sns.barplot(x=starts_df_annual.index,y='Alberta_CMA',data = starts_df_annual)
fig.get_figure().autofmt_xdate()
fig.suptitle('Starts, Alberta CMAs')
# Out:
# Text(0.5, 0.98, 'Starts,Alberta CMAs')

# %%
fig, ax = plt.subplots(figsize=(12,6))
sns.barplot(x=starts_df_annual.index,y='Alberta_exCMA',data = starts_df_annual)
fig.get_figure().autofmt_xdate()
fig.suptitle('Starts, Alberta ex CMAs')
# Out:
# Text(0.5, 0.98, 'Starts, Alberta ex CMAs')

# %%
fig, ax = plt.subplots(figsize=(12,6))
sns.barplot(x=starts_df_annual.index,y='Calgary_Edmonton',data = starts_df_annual)
fig.get_figure().autofmt_xdate()
fig.suptitle('Starts, Alberta Calgary & Edmonton')
# Out:
# Text(0.5, 0.98, 'Starts, Alberta Calgary & Edmonton')

# %%
fig, ax = plt.subplots(figsize=(12,6))
sns.barplot(x=starts_df_annual.index,y='Alberta_small_CMA',data = starts_df_annual)
fig.get_figure().autofmt_xdate()
fig.suptitle('Starts, Smaller CMAs')
# Out:
# Text(0.5, 0.98, 'Starts, Smaller CMAs')

# %%
total_sales = [i for i in list(sale_df.columns) if i[3:6]=='SAL']
total_vol=[i for i in list(sale_df.columns) if i[3:6]=='VOL']

# %%
sale_df_annual =sale_df.resample('A').sum()

# %%
sale_df['Alberta_CMA_vol']=sale_df['ACAVOLCNR_Q']+sale_df['AEDVOLCNR_Q']+sale_df['ALEVOLCNR_Q']+sale_df['AREVOLCNR_Q']
sale_df['Alberta_exCMA_vol']=sale_df['AZZVOLCNR_Q']-sale_df['Alberta_CMA_vol']
sale_df['Calgary_Edmonton_vol']=sale_df['ACAVOLCNR_Q']+sale_df['AEDVOLCNR_Q']
sale_df['Alberta_small_CMA_vol']=sale_df['Alberta_CMA_vol']-sale_df['Calgary_Edmonton_vol']

sale_df['Alberta_CMA_sales']=sale_df['ACASALUNR_Q']+sale_df['AEDSALUNR_Q']+sale_df['ALESALUNR_Q']+sale_df['ARESALUNR_Q']
sale_df['Alberta_exCMA_sales']=sale_df['AZZSALUNR_Q']-sale_df['Alberta_CMA_sales']
sale_df['Calgary_Edmonton_sales']=sale_df['ACASALUNR_Q']+sale_df['AEDSALUNR_Q']
sale_df['Alberta_small_CMA_sales']=sale_df['Alberta_CMA_sales']-sale_df['Calgary_Edmonton_sales']

# %%
fig, ax = plt.subplots(figsize=(12,6))
sns.lineplot(x=sale_df.index,y='Alberta_CMA_sales',data = sale_df)
fig.get_figure().autofmt_xdate()
fig.suptitle('Sales, Alberta CMAs')
# Out:
# Text(0.5, 0.98, 'Sales, Alberta CMAs')

# %%
fig, ax = plt.subplots(figsize=(12,6))
sns.lineplot(x=sale_df.index,y='AZZSALUNR_Q',data = sale_df)
fig.get_figure().autofmt_xdate()
fig.suptitle('Sales, Alberta')
# Out:
# Text(0.5, 0.98, 'Sales, Alberta')

# %%
fig, ax = plt.subplots(figsize=(12,6))
sns.lineplot(x=sale_df.index,y='Calgary_Edmonton_sales',data = sale_df)
fig.get_figure().autofmt_xdate()
fig.suptitle('Sales, Alberta Calgary & Edmonton')
# Out:
# Text(0.5, 0.98, 'Sales, Alberta Calgary & Edmonton')

# %%
fig, ax = plt.subplots(figsize=(12,6))
sns.lineplot(x=sale_df.index,y='Alberta_exCMA_sales',data = sale_df)
fig.get_figure().autofmt_xdate()
fig.suptitle('Sales, Alberta ex-CMAs')
# Out:
# Text(0.5, 0.98, 'Sales, Alberta ex-CMAs')

# %%
fig, ax = plt.subplots(figsize=(12,6))
sns.lineplot(x=sale_df.index,y='Alberta_small_CMA_sales',data = sale_df)
fig.get_figure().autofmt_xdate()
fig.suptitle('Sales, Alberta Smaller CMAs')
# Out:
# Text(0.5, 0.98, 'Sales, Alberta Smaller CMAs')

# %%
sale_df['Alberta_CMA_price']=sale_df['Alberta_CMA_vol']/sale_df['Alberta_CMA_sales']
sale_df['Alberta_exCMA_price']=sale_df['Alberta_exCMA_vol']/sale_df['Alberta_exCMA_sales']
sale_df['Calgary_Edmonton_price']=sale_df['Calgary_Edmonton_vol']/sale_df['Calgary_Edmonton_sales']
sale_df['Alberta_small_CMA_price']=sale_df['Alberta_small_CMA_vol']/sale_df['Alberta_small_CMA_sales']
sale_df['Alberta_price']=sale_df['AZZVOLCNR_Q']/sale_df['AZZSALUNR_Q']

# %%
fig, ax = plt.subplots(figsize=(12,6))
sns.lineplot(x=sale_df.index,y='Alberta_CMA_price',data = sale_df)
fig.get_figure().autofmt_xdate()
fig.suptitle('Average Price, Alberta CMAs (Thousands)')
# Out:
# Text(0.5, 0.98, 'Average Price, Alberta CMAs (Thousands)')

# %%
fig, ax = plt.subplots(figsize=(12,6))
sns.lineplot(x=sale_df.index,y='Alberta_price',data = sale_df)
fig.get_figure().autofmt_xdate()
fig.suptitle('Average Price, Alberta')
# Out:
# Text(0.5, 0.98, 'Average Price, Alberta')

# %%
fig, ax = plt.subplots(figsize=(12,6))
sns.lineplot(x=sale_df.index,y='Calgary_Edmonton_price',data = sale_df)
fig.get_figure().autofmt_xdate()
fig.suptitle('Average Price, Alberta Calgary & Edmonton')
# Out:
# Text(0.5, 0.98, 'Average Price, Alberta Calgary & Edmonton')

# %%
fig, ax = plt.subplots(figsize=(12,6))
sns.lineplot(x=sale_df.index,y='Alberta_exCMA_price',data = sale_df)
fig.get_figure().autofmt_xdate()
fig.suptitle('Average Price, Alberta ex-CMAs (Thousands)')
# Out:
# Text(0.5, 0.98, 'Average Price, Alberta ex-CMAs (Thousands)')

# %%
fig, ax = plt.subplots(figsize=(12,6))
sns.lineplot(x=sale_df.index,y='Alberta_small_CMA_price',data = sale_df)
fig.get_figure().autofmt_xdate()
fig.suptitle('Average Price, Alberta Smaller CMAs (Thousands)')
# Out:
# Text(0.5, 0.98, 'Average Price, Alberta Smaller CMAs (Thousands)')

# %%
sale_df.tail(10)
# Out:
#             ABRNLIUNR_Q  ABRPRICNR_Q  ABRSALUNR_Q  ABRVOLCNR_Q  ACANLIUNR_Q  \
# 2020-01-01        182.0     184386.0         77.0      14198.0       9799.0
# 2020-04-01        179.0     197662.0         95.0      18778.0       9656.0
# 2020-07-01        211.0     225951.0        133.0      30051.0      11109.0
# 2020-10-01        132.0     234108.0         92.0      21538.0       6966.0
# 2021-01-01        202.0     239260.0        119.0      28472.0      12443.0
# 2021-04-01        266.0     263359.0        188.0      49512.0      17388.0
# 2021-07-01        184.0     240811.0        152.0      36603.0      11684.0
# 2021-10-01        124.0     238385.0        116.0      27653.0       7293.0
# 2022-01-01        198.0     250284.0        166.0      41547.0      16043.0
# 2022-04-01        217.0     264821.0        151.0      39988.0      16845.0
#
#             ACAPRICNR_Q  ACASALUNR_Q  ACAVOLCNR_Q  AEDNLIUNR_Q  AEDPRICNR_Q  \
# ...
