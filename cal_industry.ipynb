# %%
from stats_can import StatsCan

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#seaborn theme
import seaborn as sns
sns.set(font='Gill Sans MT')
plt.rcParams['font.size'] = '20'

# %%
sc = StatsCan()

# %%
sc.update_tables()
# Out:
# ['17100135', '17100136']

# %%
df= sc.table_to_df('14-10-0384-01')

# %%
df
# Out:
#         REF_DATE                                    GEO         DGUID  \
# 0     2006-01-01  St. John's, Newfoundland and Labrador  2016S0503001
# 1     2006-01-01  St. John's, Newfoundland and Labrador  2016S0503001
# 2     2006-01-01  St. John's, Newfoundland and Labrador  2016S0503001
# 3     2006-01-01  St. John's, Newfoundland and Labrador  2016S0503001
# 4     2006-01-01  St. John's, Newfoundland and Labrador  2016S0503001
# ...          ...                                    ...           ...
# 10540 2020-01-01             Victoria, British Columbia  2016S0503935
# 10541 2020-01-01             Victoria, British Columbia  2016S0503935
# 10542 2020-01-01             Victoria, British Columbia  2016S0503935
# 10543 2020-01-01             Victoria, British Columbia  2016S0503935
# 10544 2020-01-01             Victoria, British Columbia  2016S0503935
#
#       North American Industry Classification System (NAICS)      UOM UOM_ID  \
# ...

# %%
calgary= df[df['GEO']=='Calgary, Alberta']

# %%
calgary['UOM'].unique()
# Out:
# ['Persons']
# Categories (1, object): ['Persons']

# %%
calgary
# Out:
#         REF_DATE               GEO         DGUID  \
# 589   2006-01-01  Calgary, Alberta  2016S0503825
# 590   2006-01-01  Calgary, Alberta  2016S0503825
# 591   2006-01-01  Calgary, Alberta  2016S0503825
# 592   2006-01-01  Calgary, Alberta  2016S0503825
# 593   2006-01-01  Calgary, Alberta  2016S0503825
# ...          ...               ...           ...
# 10445 2020-01-01  Calgary, Alberta  2016S0503825
# 10446 2020-01-01  Calgary, Alberta  2016S0503825
# 10447 2020-01-01  Calgary, Alberta  2016S0503825
# 10448 2020-01-01  Calgary, Alberta  2016S0503825
# 10449 2020-01-01  Calgary, Alberta  2016S0503825
#
#       North American Industry Classification System (NAICS)      UOM UOM_ID  \
# 589                       Total employed, all industries     Persons    249
# 590                               Goods-producing sector     Persons    249
# 591               Agriculture [111-112, 1100, 1151-1152]     Persons    249
# ...

# %%
cal_data = calgary.filter(items = ['REF_DATE','North American Industry Classification System (NAICS)','SCALAR_FACTOR','UOM', 'VALUE'])

# %%
cal_data['SCALAR_FACTOR'].unique()
# Out:
# ['thousands']
# Categories (1, object): ['thousands']

# %%
cal_pivot = cal_data.pivot(index='REF_DATE', columns = 'North American Industry Classification System (NAICS)',values ='VALUE')

# %%
cal_pivot
# Out:
# North American Industry Classification System (NAICS)  Accommodation and food services [72]  \
# REF_DATE
# 2006-01-01                                                                             41.0
# 2007-01-01                                                                             35.8
# 2008-01-01                                                                             40.9
# 2009-01-01                                                                             42.5
# 2010-01-01                                                                             40.8
# 2011-01-01                                                                             44.9
# 2012-01-01                                                                             49.6
# 2013-01-01                                                                             48.7
# 2014-01-01                                                                             49.7
# ...

# %%
cal_pivot[['Forestry, fishing, mining, quarrying, oil and gas [21, 113-114, 1153, 2100]','Services-producing sector','Goods-producing sector']].plot(figsize=(20,15))
# Out:
# <AxesSubplot:xlabel='REF_DATE'>

# %%
df_3ma = sc.table_to_df('14-10-0379-01')

# %%
df_3ma
# Out:
#          REF_DATE                                    GEO         DGUID  \
# 0      2006-03-01  St. John's, Newfoundland and Labrador  2016S0503001
# 1      2006-03-01  St. John's, Newfoundland and Labrador  2016S0503001
# 2      2006-03-01  St. John's, Newfoundland and Labrador  2016S0503001
# 3      2006-03-01  St. John's, Newfoundland and Labrador  2016S0503001
# 4      2006-03-01  St. John's, Newfoundland and Labrador  2016S0503001
# ...           ...                                    ...           ...
# 132862 2021-11-01             Victoria, British Columbia  2016S0503935
# 132863 2021-11-01             Victoria, British Columbia  2016S0503935
# 132864 2021-11-01             Victoria, British Columbia  2016S0503935
# 132865 2021-11-01             Victoria, British Columbia  2016S0503935
# 132866 2021-11-01             Victoria, British Columbia  2016S0503935
#
#        North American Industry Classification System (NAICS)      UOM UOM_ID  \
# ...

# %%
calgary_3ma = df_3ma[df_3ma['GEO']=='Calgary, Alberta']

# %%
calgary_3ma=calgary_3ma.rename({'REF_DATE':'Date'},axis=1)
cal_data_3ma = calgary_3ma.filter(items = ['Date','North American Industry Classification System (NAICS)','SCALAR_FACTOR','UOM', 'VALUE'])
cal_pivot_3ma = cal_data_3ma.pivot(index='Date', columns = 'North American Industry Classification System (NAICS)',values ='VALUE')

# %%
cal_pivot_3ma
# Out:
# North American Industry Classification System (NAICS)  Accommodation and food services [72]  \
# Date
# 2006-03-01                                                                             37.4
# 2006-04-01                                                                             38.7
# 2006-05-01                                                                             40.5
# 2006-06-01                                                                             40.9
# 2006-07-01                                                                             41.3
# ...                                                                                     ...
# 2021-07-01                                                                             39.6
# 2021-08-01                                                                             44.8
# 2021-09-01                                                                             44.0
# ...

# %%
cal_pivot_3ma['2019':]
# Out:
# North American Industry Classification System (NAICS)  Accommodation and food services [72]  \
# Date
# 2019-01-01                                                                             51.8
# 2019-02-01                                                                             53.2
# 2019-03-01                                                                             55.6
# 2019-04-01                                                                             57.7
# 2019-05-01                                                                             58.3
# 2019-06-01                                                                             58.3
# 2019-07-01                                                                             59.6
# 2019-08-01                                                                             60.1
# 2019-09-01                                                                             59.9
# ...

# %%
cal_pivot_3ma[['Goods-producing sector','Services-producing sector']].plot(figsize=(16,9),xlabel='Date')
plt.tight_layout()
plt.savefig('goods_service.png')

# %%
fig, axes = plt.subplots(nrows=4, ncols=2,figsize=(22,14))
cal_pivot_3ma[['Forestry, fishing, mining, quarrying, oil and gas [21, 113-114, 1153, 2100]','Manufacturing [31-33]','Professional, scientific and technical services [54]',"Wholesale and retail trade [41-45]",'Health care and social assistance [62]','Accommodation and food services [72]','Construction [23]','Public administration [91]']].plot(ax= axes,subplots=True)
plt.tight_layout()
plt.savefig('sector_employ.png')
# Out:
# C:\Users\Maln\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\tools.py:331: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():

# %%
fig, axes = plt.subplots(nrows=4, ncols=2,figsize=(22,14))
cal_pivot_3ma['2019':][['Forestry, fishing, mining, quarrying, oil and gas [21, 113-114, 1153, 2100]','Manufacturing [31-33]','Professional, scientific and technical services [54]',"Wholesale and retail trade [41-45]",'Health care and social assistance [62]','Accommodation and food services [72]','Construction [23]','Public administration [91]']].plot(ax=axes, subplots=True)
plt.tight_layout()
plt.savefig('sector_employ_short.png')
# Out:
# C:\Users\Maln\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\tools.py:331: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():

# %%
cal_pivot_3ma[['Forestry, fishing, mining, quarrying, oil and gas [21, 113-114, 1153, 2100]','Manufacturing [31-33]','Professional, scientific and technical services [54]',"Wholesale and retail trade [41-45]",'Health care and social assistance [62]', 'Accommodation and food services [72]']].plot.area(stacked = True,figsize=(20,15))
# Out:
# <AxesSubplot:xlabel='REF_DATE'>

# %%
cal_pivot_3ma[['Goods-producing sector','Services-producing sector']].plot.area(stacked=True,figsize=(16,9),xlabel='Date')
plt.tight_layout()
plt.savefig('goods_service_stack.png')

# %%
cal_pivot_3ma['2018':][['Goods-producing sector','Services-producing sector']].plot(figsize=(20,15))
# Out:
# <AxesSubplot:xlabel='REF_DATE'>

# %%
cal_pivot_3ma.diff(12)['2019':]
# Out:
# North American Industry Classification System (NAICS)  Accommodation and food services [72]  \
# REF_DATE
# 2019-01-01                                                                             -6.6
# 2019-02-01                                                                             -3.4
# 2019-03-01                                                                              0.7
# 2019-04-01                                                                              3.4
# 2019-05-01                                                                              2.9
# 2019-06-01                                                                              4.0
# 2019-07-01                                                                              2.5
# 2019-08-01                                                                              1.8
# 2019-09-01                                                                             -1.3
# ...

# %%
cal_pivot_3ma.diff(24)['2019':]
# Out:
# North American Industry Classification System (NAICS)  Accommodation and food services [72]  \
# REF_DATE
# 2019-01-01                                                                              3.6
# 2019-02-01                                                                              5.4
# 2019-03-01                                                                              6.8
# 2019-04-01                                                                              8.2
# 2019-05-01                                                                              5.2
# 2019-06-01                                                                              0.8
# 2019-07-01                                                                             -3.5
# 2019-08-01                                                                             -7.1
# 2019-09-01                                                                             -8.9
# ...
