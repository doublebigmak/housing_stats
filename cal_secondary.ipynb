# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd

#seaborn theme
import seaborn as sns
sns.set()
sns.set(font='Gill Sans MT')

# %% [markdown]
# https://data.calgary.ca/Business-and-Economic-Activity/Secondary-Suites/jwn6-r58y for data

# %%
s_suite = pd.read_csv('data//Secondary_Suites.csv')

# %%
s_suite['InspectionDate']=pd.to_datetime(s_suite['InspectionDate'])
s_suite['CompletionDate']=pd.to_datetime(s_suite['CompletionDate'])
s_suite=s_suite.set_index('CompletionDate')

# %%
s_suite
# Out:
#                   id                Address        BuildingAddress  \
# CompletionDate
# 2020-03-26         3      #1 2711 17A ST NW         2711 17A ST NW
# 2017-04-28      2942         7440 21A ST SE        7440G 21A ST SE
# 2019-01-30      2900        72R SETON TC SE         72 SETON TC SE
# 2020-04-01        12       #2 3435 19 AV SW          3435 19 AV SW
# 2020-02-19      1982         3820B 12 AV SE          3820 12 AV SE
# ...              ...                    ...                    ...
# 2017-02-14      2546        57 GALWAY CR SW        57 GALWAY CR SW
# 2017-01-16       537  13R ASPEN VISTA RD SW   13 ASPEN VISTA RD SW
# 2012-08-03      3206           924 42 ST SW           924 42 ST SW
# 2019-10-03       725   157B SOMERSIDE PA SW    157 SOMERSIDE PA SW
# 2013-07-12       898  180 CASTLEGREEN CL NE  180 CASTLEGREEN CL NE
#
#                           Community InspectionDate  PermitNumber  \
# CompletionDate
# 2020-03-26             CAPITOL HILL     2020-03-26  BP2020-00984
# 2017-04-28                    OGDEN     2017-04-28  BP2016-09211
# 2019-01-30                    SETON     2019-01-29  BP2018-15672
# 2020-04-01      KILLARNEY/GLENGARRY     2020-04-01  BP2020-00477
# 2020-02-19              FOREST LAWN     2020-01-23  BP2019-16694
# ...                             ...            ...           ...
# 2017-02-14                GLAMORGAN     2017-02-14  BP2016-09814
# 2017-01-16              ASPEN WOODS     2017-01-16  BP2016-07196
# 2012-08-03              ROSSCARROCK     2012-08-01  BP2011-00820
# 2019-10-03                 SOMERSET     2019-10-03  BP2019-00041
# 2013-07-12              CASTLERIDGE     2013-07-12  BP2013-03193
#
#                 StickerNumber  Ward   longitude   latitude  \
# CompletionDate
# 2020-03-26               2675     7 -114.103890  51.075947
# 2017-04-28                742     9 -114.006763  50.985504
# 2019-01-30               1281    12 -113.958180  50.869312
# 2020-04-01               2732     8 -114.135930  51.036108
# 2020-02-19               2477     9 -113.979001  51.042657
# ...                       ...   ...         ...        ...
# 2017-02-14                695     6 -114.148645  51.013827
# 2017-01-16                666     6 -114.203111  51.044233
# 2012-08-03                 47     6 -114.148027  51.044203
# 2019-10-03               1992    13 -114.095114  50.901144
# 2013-07-12                266     3 -113.957704  51.108750
#
#                                                  location
# CompletionDate
# 2020-03-26      (51.075947467293254, -114.10388995014098)
# 2017-04-28       (50.98550362288669, -114.00676302386418)
# 2019-01-30        (50.8693121451594, -113.95818016557483)
# 2020-04-01       (51.036108416554875, -114.1359302157352)
# 2020-02-19      (51.042657365202096, -113.97900095274544)
# ...                                                   ...
# 2017-02-14      (51.013827479362455, -114.14864477969608)
# 2017-01-16       (51.04423280051456, -114.20311117171786)
# 2012-08-03       (51.04420333472694, -114.14802744890122)
# 2019-10-03       (50.90114432228782, -114.09511415506464)
# 2013-07-12        (51.10874964679337, -113.9577041521661)
#
# [3294 rows x 11 columns]

# %%
s_suite['2017':'2020'].resample('M').count()['id'].plot(title='Secondary Suites Approved')

# %%
s_suite[s_suite['   ']]

# %%
st_rental = pd.read_csv('data//Short_Term_Rentals.csv')

# %% [markdown]
# https://data.calgary.ca/Business-and-Economic-Activity/Short-Term-Rentals/gzkz-5k9a for data

# %%
st_rental
# Out:
#      Business Licence Number  Business ID                        Address  \
# 0                   BL233732     15899321      302 TUSCANY SPRINGS BV NW
# 1                   BL236183     15928906            1136 SHERWOOD BV NW
# 2                   BL233824     15900442           225 RIVER ROCK PL SE
# 3                   BL233804     15900251               #201 17 13 ST NW
# 4                   BL233800     15900194                  1829 21 AV NW
# ...                      ...          ...                            ...
# 1025                BL232553     15885031       #204 830 MCDOUGALL RD NE
# 1026                BL232558     15885064              #503 111 14 AV SE
# 1027                BL232570     15885171              #1609 615 6 AV SE
# 1028                BL232573     15885205  #5201 302 SKYVIEW RANCH DR NE
# 1029                BL232576     15885221                  1213R 8 AV SE
#
#              Business Licence Type      Type of Residence Licenced Date  \
# 0     SHORT TERM RENTAL - TIER ONE              Townhouse    2020/04/27
# 1     SHORT TERM RENTAL - TIER ONE  Single/detached house    2020/08/05
# 2     SHORT TERM RENTAL - TIER ONE  Single/detached house    2020/05/01
# 3     SHORT TERM RENTAL - TIER ONE   Apartment/condo unit    2020/05/01
# 4     SHORT TERM RENTAL - TIER ONE  Single/detached house    2020/05/01
# ...                            ...                    ...           ...
# 1025  SHORT TERM RENTAL - TIER ONE   Apartment/condo unit    2020/02/24
# 1026  SHORT TERM RENTAL - TIER ONE   Apartment/condo unit    2020/02/24
# 1027  SHORT TERM RENTAL - TIER ONE   Apartment/condo unit    2020/02/24
# 1028  SHORT TERM RENTAL - TIER ONE   Apartment/condo unit    2020/02/24
# 1029  SHORT TERM RENTAL - TIER ONE       Suite in a house    2020/02/24
#
#      Licenced Expiry Date Status Description   longitude   latitude  \
# 0              2021/04/27           Licensed -114.240164  51.134564
# 1              2021/08/05           Licensed -114.147482  51.157318
# 2              2021/05/01           Licensed -114.005491  50.966623
# 3              2021/05/01           Licensed -114.093608  51.052013
# 4              2021/05/01           Licensed -114.103793  51.071278
# ...                   ...                ...         ...        ...
# 1025           2021/02/23           Licensed -114.043427  51.051026
# 1026           2021/02/23           Licensed -114.062820  51.039269
# 1027           2021/02/23           Licensed -114.050125  51.046721
# 1028           2021/02/23           Licensed -113.961216  51.159617
# 1029           2021/02/23           Licensed -114.035606  51.042497
#
#                                           Point  Ward Boundaries  \
# 0     POINT (-114.240163800036 51.134563516548)             13.0
# 1     POINT (-114.147481546444 51.157317827099)              3.0
# 2     POINT (-114.005491241757 50.966623428045)             10.0
# 3      POINT (-114.093607801116 51.05201281465)              7.0
# 4      POINT (-114.103792666692 51.07127803598)              7.0
# ...                                         ...              ...
# 1025  POINT (-114.043427258916 51.051026355382)             10.0
# 1026  POINT (-114.062819565137 51.039269498211)             14.0
# 1027   POINT (-114.05012463322 51.046720793592)              7.0
# 1028  POINT (-113.961216112577 51.159617071537)             11.0
# 1029  POINT (-114.035605832389 51.042497167594)             10.0
#
#       City Quadrants  Calgary Communities  Ward Boundaries 2013-2017
# 0                2.0                158.0                        9.0
# 1                2.0                292.0                       10.0
# 2                3.0                 19.0                        8.0
# 3                2.0                 40.0                        7.0
# 4                2.0                 63.0                        7.0
# ...              ...                  ...                        ...
# 1025             4.0                137.0                       11.0
# 1026             3.0                260.0                        5.0
# 1027             3.0                 65.0                        7.0
# 1028             4.0                 12.0                        1.0
# 1029             3.0                 54.0                       11.0
#
# [1030 rows x 15 columns]

# %%
st_rental['Licenced Date']=pd.to_datetime(st_rental['Licenced Date'])
st_rental['Licenced Expiry Date']=pd.to_datetime(st_rental['Licenced Expiry Date'])
st_rental=st_rental.set_index('Licenced Date')

# %%
st_rental.resample('M').count()
# Out:
#                Business Licence Number  Business ID  Address  \
# Licenced Date
# 2020-01-31                           1            1        1
# 2020-02-29                         780          780      772
# 2020-03-31                         123          123      123
# 2020-04-30                          21           21       21
# 2020-05-31                          34           34       34
# 2020-06-30                          36           36       36
# 2020-07-31                          27           27       27
# 2020-08-31                           8            8        8
#
#                Business Licence Type  Type of Residence  Licenced Expiry Date  \
# Licenced Date
# 2020-01-31                         1                  1                     1
# 2020-02-29                       779                778                   780
# 2020-03-31                       123                122                   123
# 2020-04-30                        21                 21                    21
# 2020-05-31                        34                 34                    34
# 2020-06-30                        36                 36                    36
# 2020-07-31                        27                 27                    27
# 2020-08-31                         8                  8                     8
#
#                Status Description  longitude  latitude  Point  \
# Licenced Date
# 2020-01-31                      1          1         1      1
# 2020-02-29                    780        772       772    772
# 2020-03-31                    123        123       123    123
# 2020-04-30                     21         21        21     21
# 2020-05-31                     34         34        34     34
# 2020-06-30                     36         36        36     36
# 2020-07-31                     27         27        27     27
# 2020-08-31                      8          8         8      8
#
#                Ward Boundaries  City Quadrants  Calgary Communities  \
# Licenced Date
# 2020-01-31                   1               1                    1
# 2020-02-29                 772             772                  772
# 2020-03-31                 123             123                  123
# 2020-04-30                  21              21                   21
# 2020-05-31                  34              34                   34
# 2020-06-30                  36              36                   36
# 2020-07-31                  27              27                   27
# 2020-08-31                   8               8                    8
#
#                Ward Boundaries 2013-2017
# Licenced Date
# 2020-01-31                             1
# 2020-02-29                           772
# 2020-03-31                           123
# 2020-04-30                            21
# 2020-05-31                            34
# 2020-06-30                            36
# 2020-07-31                            27
# 2020-08-31                             8
