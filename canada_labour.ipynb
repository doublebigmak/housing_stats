# %%
from stats_can import StatsCan

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#seaborn theme
import seaborn as sns
sns.set(font='Gill Sans MT')

# %%
sc = StatsCan()
df = sc.table_to_df('14-10-0017-01')
#sc.update_tables()

# %%
df
# Out:
#           REF_DATE               GEO           DGUID  \
# 0       1976-01-01            Canada  2016A000011124
# 1       1976-01-01            Canada  2016A000011124
# 2       1976-01-01            Canada  2016A000011124
# 3       1976-01-01            Canada  2016A000011124
# 4       1976-01-01            Canada  2016A000011124
# ...            ...               ...             ...
# 3876835 2020-06-01  British Columbia     2016A000259
# 3876836 2020-06-01  British Columbia     2016A000259
# 3876837 2020-06-01  British Columbia     2016A000259
# 3876838 2020-06-01  British Columbia     2016A000259
# 3876839 2020-06-01  British Columbia     2016A000259
#
#         Labour force characteristics         Sex          Age group  \
# 0                         Population  Both sexes  15 years and over
# 1                         Population  Both sexes     15 to 24 years
# 2                         Population  Both sexes  25 years and over
# ...

# %%
canada = df[df['GEO']=='Canada']

# %%
can_ft = canada[canada['Labour force characteristics']=='Full-time employment']

# %%
emp_num = can_ft[(can_ft['Age group']=='15 years and over') & (can_ft['Sex']=='Both sexes') & (can_ft['UOM']=='Persons')]

# %%
emp_num.set_index('REF_DATE')['2014':'2020'].plot(figsize=(14,6))

# %%
can_ft = canada[canada['Labour force characteristics']=='Part-time employment']
emp_num = can_ft[(can_ft['Age group']=='15 years and over') & (can_ft['Sex']=='Both sexes') & (can_ft['UOM']=='Persons')]
emp_num.set_index('REF_DATE')['2014':'2020'].plot(figsize=(14,6))
