# %%
from stats_can import StatsCan

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#seaborn theme
import seaborn as sns
sns.set(font='Gill Sans MT')

# %%
sc = StatsCan()
df = sc.table_to_df('14-10-0017-01')
#sc.update_tables()

# %%
df
# Out:
#           REF_DATE               GEO           DGUID  \
# 0       1976-01-01            Canada  2016A000011124
# 1       1976-01-01            Canada  2016A000011124
# 2       1976-01-01            Canada  2016A000011124
# 3       1976-01-01            Canada  2016A000011124
# 4       1976-01-01            Canada  2016A000011124
# ...            ...               ...             ...
# 3905875 2020-10-01  British Columbia     2016A000259
# 3905876 2020-10-01  British Columbia     2016A000259
# 3905877 2020-10-01  British Columbia     2016A000259
# 3905878 2020-10-01  British Columbia     2016A000259
# 3905879 2020-10-01  British Columbia     2016A000259
#
#         Labour force characteristics         Sex          Age group  \
# 0                         Population  Both sexes  15 years and over
# 1                         Population  Both sexes     15 to 24 years
# 2                         Population  Both sexes  25 years and over
# ...

# %%
canada = df[df['GEO']=='Canada']

# %%
can_ft = canada[canada['Labour force characteristics']=='Full-time employment']

# %%
emp_num = can_ft[(can_ft['Age group']=='15 years and over') & (can_ft['Sex']=='Both sexes') & (can_ft['UOM']=='Persons')]

# %%
emp_num.set_index('REF_DATE')['2014':'2020'].plot(figsize=(14,6))
# Out:
# <AxesSubplot:xlabel='REF_DATE'>

# %%
can_ft = canada[canada['Labour force characteristics']=='Part-time employment']
emp_num = can_ft[(can_ft['Age group']=='15 years and over') & (can_ft['Sex']=='Both sexes') & (can_ft['UOM']=='Persons')]
emp_num.set_index('REF_DATE')['2014':'2020'].plot(figsize=(14,6))
# Out:
# <AxesSubplot:xlabel='REF_DATE'>

# %%
alberta = df[df['GEO']=='Alberta']

# %%
ab_ft = alberta[alberta['Labour force characteristics']=='Full-time employment']
ab_emp = ab_ft[(ab_ft['Age group']=='15 years and over') & (ab_ft['Sex']=='Both sexes') & (ab_ft['UOM']=='Persons')]

# %%
ab_emp.set_index('REF_DATE')['2014':'2020'].plot(figsize=(14,6))
# Out:
# <AxesSubplot:xlabel='REF_DATE'>

# %%
ab_emp
# Out:
#           REF_DATE      GEO        DGUID Labour force characteristics  \
# 6138    1976-01-01  Alberta  2016A000248         Full-time employment
# 13398   1976-02-01  Alberta  2016A000248         Full-time employment
# 20658   1976-03-01  Alberta  2016A000248         Full-time employment
# 27918   1976-04-01  Alberta  2016A000248         Full-time employment
# 35178   1976-05-01  Alberta  2016A000248         Full-time employment
# ...            ...      ...          ...                          ...
# 3875718 2020-06-01  Alberta  2016A000248         Full-time employment
# 3882978 2020-07-01  Alberta  2016A000248         Full-time employment
# 3890238 2020-08-01  Alberta  2016A000248         Full-time employment
# 3897498 2020-09-01  Alberta  2016A000248         Full-time employment
# 3904758 2020-10-01  Alberta  2016A000248         Full-time employment
#
#                 Sex          Age group      UOM UOM_ID SCALAR_FACTOR  \
# ...

# %%
ab_pt = alberta[alberta['Labour force characteristics']=='Part-time employment']
ab_pt_emp = ab_pt[(ab_pt['Age group']=='15 years and over') & (ab_pt['Sex']=='Both sexes') & (ab_pt['UOM']=='Persons')]

# %%
ab_pt_emp.set_index('REF_DATE')['2014':'2020'].plot(figsize=(14,6))
# Out:
# <AxesSubplot:xlabel='REF_DATE'>

# %%
ab_pr = alberta[alberta['Labour force characteristics']=='Participation rate']
ab_pr = ab_pr[(ab_pr['Age group']=='15 years and over') & (ab_pr['Sex']=='Both sexes') & (ab_pr['UOM']=='Percentage')]

# %%
ab_pr.set_index('REF_DATE')['2014':'2020'].plot(figsize=(14,6))
# Out:
# <AxesSubplot:xlabel='REF_DATE'>

# %%
ab_emp_rate = alberta[alberta['Labour force characteristics']=='Unemployment rate']
ab_emp_rate = ab_emp_rate[(ab_emp_rate['Age group']=='15 years and over') & (ab_emp_rate['Sex']=='Both sexes') & (ab_emp_rate['UOM']=='Percentage')]

# %%
ab_emp_rate.set_index('REF_DATE')['2014':'2020'].plot(figsize=(14,6))
# Out:
# <AxesSubplot:xlabel='REF_DATE'>
