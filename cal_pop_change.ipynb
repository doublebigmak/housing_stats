# %%
from stats_can import StatsCan

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#seaborn theme
import seaborn as sns
sns.set()

# %%
sc = StatsCan()

# %%
sc.update_tables()
df = sc.table_to_df("17-10-0136-01")

# %%
df
# Out:
#           REF_DATE                                                GEO DGUID  \
# 0        2006/2007  All census metropolitan areas and census agglo...   NaN
# 1        2006/2007  All census metropolitan areas and census agglo...   NaN
# 2        2006/2007  All census metropolitan areas and census agglo...   NaN
# 3        2006/2007  All census metropolitan areas and census agglo...   NaN
# 4        2006/2007  All census metropolitan areas and census agglo...   NaN
# ...            ...                                                ...   ...
# 6914677  2018/2019  Area outside census metropolitan areas and cen...   NaN
# 6914678  2018/2019  Area outside census metropolitan areas and cen...   NaN
# 6914679  2018/2019  Area outside census metropolitan areas and cen...   NaN
# 6914680  2018/2019  Area outside census metropolitan areas and cen...   NaN
# 6914681  2018/2019  Area outside census metropolitan areas and cen...   NaN
#
# ...

# %%
calgary = df[df['GEO']=="Calgary (CMA), Alberta"]

# %%
calgary
# Out:
#           REF_DATE                     GEO         DGUID  \
# 101772   2006/2007  Calgary (CMA), Alberta  2016S0503825
# 101773   2006/2007  Calgary (CMA), Alberta  2016S0503825
# 101774   2006/2007  Calgary (CMA), Alberta  2016S0503825
# 101775   2006/2007  Calgary (CMA), Alberta  2016S0503825
# 101776   2006/2007  Calgary (CMA), Alberta  2016S0503825
# ...            ...                     ...           ...
# 6522571  2018/2019  Calgary (CMA), Alberta  2016S0503825
# 6522572  2018/2019  Calgary (CMA), Alberta  2016S0503825
# 6522573  2018/2019  Calgary (CMA), Alberta  2016S0503825
# 6522574  2018/2019  Calgary (CMA), Alberta  2016S0503825
# 6522575  2018/2019  Calgary (CMA), Alberta  2016S0503825
#
#         Components of population growth         Sex           Age group  \
# 101772                           Births  Both sexes            All ages
# 101773                           Births  Both sexes             -1 year
# ...

# %%
calgary['Components of population growth'].unique()
# Out:
# array(['Births', 'Deaths', 'Immigrants', 'Emigrants',
#        'Returning emigrants', 'Net temporary emigration',
#        'Net interprovincial migration', 'Net intraprovincial migration',
#        'Net non-permanent residents', 'Residual deviation'], dtype=object)

# %%
calgary['STATUS'].unique()
# Out:
# [NaN]
# Categories (0, float64): []

# %%
calgary = calgary.filter(items = ['REF_DATE','Components of population growth','Sex','Age group', 'VALUE'])

# %%
calgary
# Out:
#           REF_DATE Components of population growth         Sex  \
# 101772   2006/2007                          Births  Both sexes
# 101773   2006/2007                          Births  Both sexes
# 101774   2006/2007                          Births       Males
# 101775   2006/2007                          Births       Males
# 101776   2006/2007                          Births     Females
# ...            ...                             ...         ...
# 6522571  2018/2019     Net non-permanent residents     Females
# 6522572  2018/2019     Net non-permanent residents     Females
# 6522573  2018/2019     Net non-permanent residents     Females
# 6522574  2018/2019     Net non-permanent residents     Females
# 6522575  2018/2019     Net non-permanent residents     Females
#
#                   Age group    VALUE
# 101772             All ages  15529.0
# 101773              -1 year  15529.0
# 101774             All ages   7971.0
# 101775              -1 year   7971.0
# ...

# %%
calgary[(calgary['Sex']=='Both sexes') & (calgary['Age group'] == 'All ages')].pivot(index='REF_DATE', columns = 'Components of population growth',values ='VALUE')
# Out:
# Components of population growth   Births  Deaths  Emigrants  Immigrants  \
# REF_DATE
# 2006/2007                        15529.0  5434.0     3609.0     11122.0
# 2007/2008                        16304.0  5469.0     3981.0     12638.0
# 2008/2009                        16894.0  5598.0     4012.0     13356.0
# 2009/2010                        16985.0  5688.0     3649.0     14917.0
# 2010/2011                        16799.0  5805.0     3770.0     15112.0
# 2011/2012                        16911.0  5720.0     4373.0     16024.0
# 2012/2013                        17421.0  6076.0     4264.0     17677.0
# 2013/2014                        17965.0  5996.0     4189.0     18543.0
# 2014/2015                        18483.0  6452.0     4726.0     18543.0
# 2015/2016                        18768.0  6454.0     4808.0     24859.0
# 2016/2017                        18075.0  6944.0     4451.0     18886.0
# 2017/2018                        17743.0  7244.0     4557.0     17425.0
# ...

# %%
cal_frame = calgary[(calgary['Sex']=='Both sexes') & (calgary['Age group'] == 'All ages')].pivot(index='REF_DATE', columns = 'Components of population growth',values ='VALUE')

# %%
cal_frame
# Out:
# Components of population growth   Births  Deaths  Emigrants  Immigrants  \
# REF_DATE
# 2006/2007                        15529.0  5434.0     3609.0     11122.0
# 2007/2008                        16304.0  5469.0     3981.0     12638.0
# 2008/2009                        16894.0  5598.0     4012.0     13356.0
# 2009/2010                        16985.0  5688.0     3649.0     14917.0
# 2010/2011                        16799.0  5805.0     3770.0     15112.0
# 2011/2012                        16911.0  5720.0     4373.0     16024.0
# 2012/2013                        17421.0  6076.0     4264.0     17677.0
# 2013/2014                        17965.0  5996.0     4189.0     18543.0
# 2014/2015                        18483.0  6452.0     4726.0     18543.0
# 2015/2016                        18768.0  6454.0     4808.0     24859.0
# 2016/2017                        18075.0  6944.0     4451.0     18886.0
# 2017/2018                        17743.0  7244.0     4557.0     17425.0
# ...

# %%
cal_frame.index
# Out:
# Index(['2006/2007', '2007/2008', '2008/2009', '2009/2010', '2010/2011',
#        '2011/2012', '2012/2013', '2013/2014', '2014/2015', '2015/2016',
#        '2016/2017', '2017/2018', '2018/2019'],
#       dtype='object', name='REF_DATE')

# %%
cal_frame.plot(figsize=(12,6),kind='bar')

# %%
cal_frame.plot(figsize=(16,6),kind='bar')

# %%
plt.figure(figsize=(20,14))
sns.barplot(x='REF_DATE',y = 'VALUE', hue='Components of population growth', data= calgary[(calgary['Sex']=='Both sexes') & (calgary['Age group'] == 'All ages')])

# %%
cal_frame['Net_international_migration']=cal_frame['Immigrants']-cal_frame['Emigrants']+cal_frame['Net non-permanent residents']+cal_frame['Returning emigrants']-cal_frame['Net temporary emigration']
cal_frame['Net_growth']=cal_frame['Births']-cal_frame['Deaths']

cal_frame['Net_pop']=cal_frame['Net interprovincial migration']+cal_frame['Net intraprovincial migration'] + cal_frame['Net_international_migration'] +cal_frame['Net_growth']

# %%
cal_frame[['Net interprovincial migration','Net_growth', 'Net non-permanent residents', 'Net_international_migration', 'Net intraprovincial migration', 'Immigrants']].plot(figsize=(20,14),kind='bar', title='Components of Migration')
plt.savefig('migration_components.png')

# %%
cal_frame
# Out:
# Components of population growth   Births  Deaths  Emigrants  Immigrants  \
# REF_DATE
# 2006/2007                        15529.0  5434.0     3609.0     11122.0
# 2007/2008                        16304.0  5469.0     3981.0     12638.0
# 2008/2009                        16894.0  5598.0     4012.0     13356.0
# 2009/2010                        16985.0  5688.0     3649.0     14917.0
# 2010/2011                        16799.0  5805.0     3770.0     15112.0
# 2011/2012                        16911.0  5720.0     4373.0     16024.0
# 2012/2013                        17421.0  6076.0     4264.0     17677.0
# 2013/2014                        17965.0  5996.0     4189.0     18543.0
# 2014/2015                        18483.0  6452.0     4726.0     18543.0
# 2015/2016                        18768.0  6454.0     4808.0     24859.0
# 2016/2017                        18075.0  6944.0     4451.0     18886.0
# 2017/2018                        17743.0  7244.0     4557.0     17425.0
# ...

# %%
plt.figure(figsize=(20,14))
sns.lineplot(x=cal_frame.index, y = 'Net_pop', data = cal_frame)

# %%
cal_frame.fillna(value=0, inplace=True)
cal_frame['tot_migrate']=cal_frame['Net_pop']-cal_frame['Net temporary emigration']+cal_frame['Residual deviation']

# %%
cal_frame
# Out:
# Components of population growth   Births  Deaths  Emigrants  Immigrants  \
# REF_DATE
# 2006/2007                        15529.0  5434.0     3609.0     11122.0
# 2007/2008                        16304.0  5469.0     3981.0     12638.0
# 2008/2009                        16894.0  5598.0     4012.0     13356.0
# 2009/2010                        16985.0  5688.0     3649.0     14917.0
# 2010/2011                        16799.0  5805.0     3770.0     15112.0
# 2011/2012                        16911.0  5720.0     4373.0     16024.0
# 2012/2013                        17421.0  6076.0     4264.0     17677.0
# 2013/2014                        17965.0  5996.0     4189.0     18543.0
# 2014/2015                        18483.0  6452.0     4726.0     18543.0
# 2015/2016                        18768.0  6454.0     4808.0     24859.0
# 2016/2017                        18075.0  6944.0     4451.0     18886.0
# 2017/2018                        17743.0  7244.0     4557.0     17425.0
# ...

# %%
plt.figure(figsize=(20,14))
sns.lineplot(x=cal_frame.index, y = 'Net_pop', data = cal_frame)
sns.lineplot(x=cal_frame.index, y = 'tot_migrate', data = cal_frame)

# %%
cal_frame['Net_pop'].to_csv('total_migration.csv')

# %%
cal_frame['Net_immigration']/(cal_frame['Net_pop'] + cal_frame['Net_growth'])
# Out:
# REF_DATE
# 2006/2007    0.227964
# 2007/2008    0.254363
# 2008/2009    0.265108
# 2009/2010    0.517783
# 2010/2011    0.444837
# 2011/2012    0.292064
# 2012/2013    0.279752
# 2013/2014    0.314470
# 2014/2015    0.451772
# 2015/2016    0.747697
# 2016/2017    0.645601
# 2017/2018    0.494638
# 2018/2019    0.434139
# dtype: float64
