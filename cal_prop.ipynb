# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
import seaborn as sns
import stats_pkg

# %%
database_name = '.\\cal_prop.sqlite'
variables = ['ROLL_YEAR','ASSESSED_VALUE','ASSESSMENT_CLASS_DESCRIPTION','RE_ASSESSED_VALUE','COMM_NAME','LAND_USE_DESIGNATION','LAND_SIZE_SF','LATITUDE','LONGITUDE','POINT']
df = stats_pkg.read_database(database_name,2013,2021,variables=variables)
# Out:
# Reading database from .\cal_prop.sqlite
# read complete

# %%
df = df[df['ASSESSMENT_CLASS_DESCRIPTION']=='Residential']

# %%
df

# %%
geo_df = gpd.GeoDataFrame(df, geometry = gpd.points_from_xy(df.LONGITUDE,df.LATITUDE), crs='EPSG:4326')
# Out:
# Exception ignored in: <function BaseGeometry.__del__ at 0x0000023DF59C24C0>
# Traceback (most recent call last):
#   File "C:\Users\mmak\AppData\Local\Continuum\anaconda3\envs\geo_env\lib\site-packages\shapely\geometry\base.py", line 242, in __del__
#     self.empty(val=None)
#   File "C:\Users\mmak\AppData\Local\Continuum\anaconda3\envs\geo_env\lib\site-packages\shapely\geometry\base.py", line 227, in empty
#     self._lgeos.GEOSGeom_destroy(self.__geom__)
# KeyboardInterrupt:

# %%
geo_df
# Out:
#          ROLL_YEAR  ASSESSED_VALUE ASSESSMENT_CLASS_DESCRIPTION  \
# 8             2017        295000.0                  Residential
# 11            2017        470000.0                  Residential
# 12            2017        498500.0                  Residential
# 13            2017        481000.0                  Residential
# 14            2017        450000.0                  Residential
# ...            ...             ...                          ...
# 4579986       2021        302000.0                  Residential
# 4579987       2021        235000.0                  Residential
# 4579988       2021        293500.0                  Residential
# 4579989       2021        235000.0                  Residential
# 4579990       2021        302000.0                  Residential
#
#          RE_ASSESSED_VALUE                      COMM_NAME  \
# 8                 295000.0  CALGARY INTERNATIONAL AIRPORT
# 11                470000.0                   SADDLE RIDGE
# ...
